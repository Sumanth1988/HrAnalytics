# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense


train_data=pd.read_csv('train_LZdllcl.csv')
test_data=pd.read_csv('test.csv')

train_data['KPIs_met']=train_data['KPIs_met >80%']
test_data['KPIs_met']=test_data['KPIs_met >80%']

train_data['awards_won']=train_data['awards_won?']
test_data['awards_won']=test_data['awards_won?']

train_data=train_data.drop(['KPIs_met >80%'],axis=1)
test_data=test_data.drop(['KPIs_met >80%'],axis=1)
train_data=train_data.drop(['awards_won?'],axis=1)
test_data=test_data.drop(['awards_won?'],axis=1)

train_data['gender']=train_data['gender'].apply(lambda x: 1 if (x =='f') else 0)
train_data['recruitment_channel']=train_data['recruitment_channel'].apply(lambda x:1 if (x=='sourcing') else 0)
train_data['education']=train_data['education'].apply(lambda x:-1 if(pd.isnull(x)) else x)
train_data['education']=train_data['education'].apply(lambda x:0 if(x=='Bachelor\'s' and (pd.notnull(x))) else 1)
train_data['previous_year_rating']=train_data['previous_year_rating'].apply(lambda x:0.0 if(pd.isnull(x)) else x)
train_data['department']=train_data['department'].apply(lambda x:1 if(x=='Sales & Marketing') else x)
train_data['department']=train_data['department'].apply(lambda x:2 if(x=='Operations') else x)
train_data['department']=train_data['department'].apply(lambda x:3 if(x=='Technology') else x)
train_data['department']=train_data['department'].apply(lambda x:4 if(x=='Analytics') else x)
train_data['department']=train_data['department'].apply(lambda x:5 if(x=='R&D') else x)
train_data['department']=train_data['department'].apply(lambda x:6 if(x=='Procurement') else x)
train_data['department']=train_data['department'].apply(lambda x:7 if(x=='Finance') else x)
train_data['department']=train_data['department'].apply(lambda x:8 if(x=='HR') else x)
train_data['department']=train_data['department'].apply(lambda x:9 if(x=='Legal') else x)

test_data['gender']=test_data['gender'].apply(lambda x: 1 if (x =='f') else 0)
test_data['recruitment_channel']=test_data['recruitment_channel'].apply(lambda x:1 if (x=='sourcing') else 0)
test_data['education']=test_data['education'].apply(lambda x:-1 if(pd.isnull(x)) else x)
test_data['education']=test_data['education'].apply(lambda x:0 if(x=='Bachelor\'s' and (pd.notnull(x))) else 1)
test_data['previous_year_rating']=test_data['previous_year_rating'].apply(lambda x:0.0 if(pd.isnull(x)) else x)
test_data['department']=test_data['department'].apply(lambda x:1 if(x=='Sales & Marketing') else x)
test_data['department']=test_data['department'].apply(lambda x:2 if(x=='Operations') else x)
test_data['department']=test_data['department'].apply(lambda x:3 if(x=='Technology') else x)
test_data['department']=test_data['department'].apply(lambda x:4 if(x=='Analytics') else x)
test_data['department']=test_data['department'].apply(lambda x:5 if(x=='R&D') else x)
test_data['department']=test_data['department'].apply(lambda x:6 if(x=='Procurement') else x)
test_data['department']=test_data['department'].apply(lambda x:7 if(x=='Finance') else x)
test_data['department']=test_data['department'].apply(lambda x:8 if(x=='HR') else x)
test_data['department']=test_data['department'].apply(lambda x:9 if(x=='Legal') else x)

X_train=train_data[['department','education','gender'
  ,'recruitment_channel','no_of_trainings','age'
  ,'previous_year_rating','length_of_service','KPIs_met',
  'awards_won','avg_training_score']]

y_train=train_data[['is_promoted']]

X_test=test_data[['department','education','gender'
  ,'recruitment_channel','no_of_trainings','age'
  ,'previous_year_rating','length_of_service','KPIs_met',
  'awards_won','avg_training_score']]

y_train=train_data[['is_promoted']]

model = Sequential()
# 16 Neurons, expects input of 11 features. 
# Play around with the number of neurons!!
model.add(Dense(11, input_dim=11, activation='relu'))
# Add another Densely Connected layer (every neuron connected to every neuron in the next layer)
model.add(Dense(16, activation='relu'))
# Last layer simple sigmoid function to output 0 or 1 (our label)
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

model.fit(X_train,y_train,epochs=100,verbose=2)

predictions=model.predict_classes(X_test)

test_data['is_promoted']=predictions

test_data[['employee_id','is_promoted']].to_csv("Submissions.csv",index=False)
# Out:
# Epoch 1/100
#  - 3s - loss: 0.3776 - acc: 0.9012
# Epoch 2/100
#  - 3s - loss: 0.2626 - acc: 0.9156
# Epoch 3/100
#  - 3s - loss: 0.2560 - acc: 0.9165
# Epoch 4/100
#  - 3s - loss: 0.2480 - acc: 0.9182
# Epoch 5/100
#  - 3s - loss: 0.2423 - acc: 0.9200
# Epoch 6/100
#  - 2s - loss: 0.2378 - acc: 0.9210
# Epoch 7/100
#  - 2s - loss: 0.2316 - acc: 0.9234
# Epoch 8/100
#  - 3s - loss: 0.2277 - acc: 0.9240
# Epoch 9/100
#  - 2s - loss: 0.2250 - acc: 0.9243
# Epoch 10/100
#  - 2s - loss: 0.2219 - acc: 0.9260
# Epoch 11/100
#  - 2s - loss: 0.2182 - acc: 0.9272
# Epoch 12/100
#  - 2s - loss: 0.2158 - acc: 0.9278
# Epoch 13/100
#  - 3s - loss: 0.2142 - acc: 0.9284
# Epoch 14/100
#  - 3s - loss: 0.2130 - acc: 0.9283
# Epoch 15/100
#  - 4s - loss: 0.2090 - acc: 0.9297
# Epoch 16/100
#  - 3s - loss: 0.2077 - acc: 0.9299
# Epoch 17/100
#  - 3s - loss: 0.2059 - acc: 0.9305
# Epoch 18/100
#  - 3s - loss: 0.2058 - acc: 0.9306
# Epoch 19/100
#  - 3s - loss: 0.2037 - acc: 0.9309
# Epoch 20/100
#  - 3s - loss: 0.2033 - acc: 0.9308
# Epoch 21/100
#  - 4s - loss: 0.2026 - acc: 0.9307
# Epoch 22/100
#  - 3s - loss: 0.2023 - acc: 0.9304
# Epoch 23/100
#  - 3s - loss: 0.2015 - acc: 0.9313
# Epoch 24/100
#  - 2s - loss: 0.2002 - acc: 0.9313
# Epoch 25/100
#  - 2s - loss: 0.2005 - acc: 0.9316
# Epoch 26/100
#  - 2s - loss: 0.1984 - acc: 0.9317
# Epoch 27/100
#  - 3s - loss: 0.1975 - acc: 0.9320
# Epoch 28/100
#  - 2s - loss: 0.1983 - acc: 0.9317
# Epoch 29/100
#  - 3s - loss: 0.1961 - acc: 0.9321
# Epoch 30/100
#  - 3s - loss: 0.1965 - acc: 0.9320
# Epoch 31/100
#  - 3s - loss: 0.1960 - acc: 0.9328
# Epoch 32/100
#  - 2s - loss: 0.1957 - acc: 0.9326
# Epoch 33/100
#  - 3s - loss: 0.1953 - acc: 0.9326
# Epoch 34/100
#  - 3s - loss: 0.1936 - acc: 0.9331
# Epoch 35/100
#  - 3s - loss: 0.1942 - acc: 0.9329
# Epoch 36/100
#  - 3s - loss: 0.1919 - acc: 0.9332
# Epoch 37/100
#  - 3s - loss: 0.1918 - acc: 0.9336
# Epoch 38/100
#  - 2s - loss: 0.1918 - acc: 0.9338
# Epoch 39/100
#  - 3s - loss: 0.1910 - acc: 0.9333
# Epoch 40/100
#  - 2s - loss: 0.1904 - acc: 0.9340
# Epoch 41/100
#  - 3s - loss: 0.1905 - acc: 0.9335
# Epoch 42/100
#  - 2s - loss: 0.1901 - acc: 0.9343
# Epoch 43/100
#  - 2s - loss: 0.1896 - acc: 0.9338
# Epoch 44/100
#  - 2s - loss: 0.1900 - acc: 0.9333
# Epoch 45/100
#  - 3s - loss: 0.1880 - acc: 0.9345
# Epoch 46/100
#  - 2s - loss: 0.1886 - acc: 0.9342
# Epoch 47/100
#  - 2s - loss: 0.1893 - acc: 0.9339
# Epoch 48/100
#  - 2s - loss: 0.1889 - acc: 0.9337
# Epoch 49/100
#  - 2s - loss: 0.1878 - acc: 0.9343
# Epoch 50/100
#  - 2s - loss: 0.1881 - acc: 0.9344
# Epoch 51/100
#  - 2s - loss: 0.1871 - acc: 0.9344
# Epoch 52/100
#  - 3s - loss: 0.1874 - acc: 0.9344
# Epoch 53/100
#  - 2s - loss: 0.1872 - acc: 0.9343
# Epoch 54/100
#  - 3s - loss: 0.1865 - acc: 0.9348
# Epoch 55/100
#  - 3s - loss: 0.1870 - acc: 0.9349
# Epoch 56/100
#  - 3s - loss: 0.1873 - acc: 0.9349
# Epoch 57/100
#  - 3s - loss: 0.1870 - acc: 0.9344
# Epoch 58/100
#  - 3s - loss: 0.1856 - acc: 0.9351
# Epoch 59/100
#  - 3s - loss: 0.1871 - acc: 0.9345
# Epoch 60/100
#  - 3s - loss: 0.1863 - acc: 0.9352
# Epoch 61/100
#  - 3s - loss: 0.1850 - acc: 0.9350
# Epoch 62/100
#  - 3s - loss: 0.1855 - acc: 0.9351
# Epoch 63/100
#  - 2s - loss: 0.1847 - acc: 0.9350
# Epoch 64/100
#  - 3s - loss: 0.1853 - acc: 0.9351
# Epoch 65/100
#  - 3s - loss: 0.1862 - acc: 0.9354
# Epoch 66/100
#  - 3s - loss: 0.1845 - acc: 0.9356
# Epoch 67/100
#  - 3s - loss: 0.1846 - acc: 0.9354
# Epoch 68/100
#  - 3s - loss: 0.1844 - acc: 0.9356
# Epoch 69/100
#  - 2s - loss: 0.1838 - acc: 0.9358
# Epoch 70/100
#  - 2s - loss: 0.1845 - acc: 0.9357
# Epoch 71/100
#  - 2s - loss: 0.1833 - acc: 0.9357
# Epoch 72/100
#  - 3s - loss: 0.1843 - acc: 0.9362
# Epoch 73/100
#  - 2s - loss: 0.1839 - acc: 0.9362
# Epoch 74/100
#  - 3s - loss: 0.1821 - acc: 0.9367
# Epoch 75/100
#  - 3s - loss: 0.1827 - acc: 0.9367
# Epoch 76/100
#  - 2s - loss: 0.1833 - acc: 0.9363
# Epoch 77/100
#  - 2s - loss: 0.1832 - acc: 0.9359
# Epoch 78/100
#  - 3s - loss: 0.1828 - acc: 0.9366
# Epoch 79/100
#  - 3s - loss: 0.1826 - acc: 0.9363
# Epoch 80/100
#  - 3s - loss: 0.1820 - acc: 0.9368
# Epoch 81/100
#  - 3s - loss: 0.1821 - acc: 0.9370
# Epoch 82/100
#  - 2s - loss: 0.1817 - acc: 0.9371
# Epoch 83/100
#  - 3s - loss: 0.1809 - acc: 0.9375
# Epoch 84/100
#  - 3s - loss: 0.1815 - acc: 0.9371
# Epoch 85/100
#  - 3s - loss: 0.1813 - acc: 0.9372
# Epoch 86/100
#  - 3s - loss: 0.1815 - acc: 0.9373
# Epoch 87/100
#  - 2s - loss: 0.1807 - acc: 0.9373
# Epoch 88/100
#  - 2s - loss: 0.1810 - acc: 0.9374
# Epoch 89/100
#  - 3s - loss: 0.1802 - acc: 0.9380
# Epoch 90/100
#  - 2s - loss: 0.1795 - acc: 0.9381
# Epoch 91/100
#  - 3s - loss: 0.1809 - acc: 0.9375
# Epoch 92/100
#  - 3s - loss: 0.1795 - acc: 0.9379
# Epoch 93/100
#  - 3s - loss: 0.1798 - acc: 0.9379
# Epoch 94/100
#  - 3s - loss: 0.1793 - acc: 0.9380
# Epoch 95/100
#  - 3s - loss: 0.1793 - acc: 0.9382
# Epoch 96/100
#  - 3s - loss: 0.1797 - acc: 0.9383
# Epoch 97/100
#  - 2s - loss: 0.1781 - acc: 0.9387
# Epoch 98/100
#  - 2s - loss: 0.1789 - acc: 0.9381
# Epoch 99/100
#  - 2s - loss: 0.1792 - acc: 0.9384
# Epoch 100/100
#  - 3s - loss: 0.1785 - acc: 0.9386
